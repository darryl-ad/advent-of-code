# %%
#Define classes needed for datastructure

class node:
    """ A node in a data tree. Represents a directory """
    def __init__(self, name, ID, parentID):
        self.name = name
        self.ID = ID
        self.parentID = parentID
        self.childrenID = []
        self.files = []
        self.filesizes = []
        self.total_contents_size = 0
        self.total_node_size = 0
        
    def addChild(self, childID):
        self.childrenID.append(childID)
    
    def addFile(self, filesize, file):
        self.files.append(file)
        self.filesizes.append(filesize)


class tree:
    """ 
    Creates a data tree structure out of nodes, based reading the lines in the terminal output.
    Then adds up the contents (file) sizes in each node (directory)
    Then sweeps through the nodes recursively, to get the size of each directory level (includes sub-directories) 
    """
    
    def __init__(self, terminal_output, debug=False):
        self.terminal_out = terminal_output
        self.nodes = [node("/", 0, None)] # Root node, name "/", ID 0, no parents
        self.nodeIDs = {"/" : 0}          # node name:ID lookup
        self.currentNode = 0              # Store what node we are in
        self.nodeSizes = 0                # Size of each node
        
        if not debug:
            # Go through the terminal output to create the datastructure
            self.processLines()
            
            # Add up filesizes in each node
            self.sum_contents()
            
            # Sweep through the nodes recursively adding up the total size of everything below each node
            # Start at the root (node 0)
            print("SUMMING TOTAL NODE SIZES")
            print("------------------------")
            self.nodeSweep(0)
            
            # Calculate the sum of all node sizes below 100000
            self.getAnswer(100000)
        
    def processLines(self):
        """ 
        Goes through each line, performing the commands and creating the data structure
        Calls self.readLine() at each line
        """
        
        print("READING LINES")
        print("----------------------")
        for line in self.terminal_out:
            print("line", line)
            self.readLine(line)
        print("\n")
    
    def readLine(self, line):
        """ Reads an individual line in the terminal output, and processes the command, or stores the file"""
        
        splitLine = line.split()
        
        if splitLine[0] == "$" and splitLine[1] == "cd": 
            # $ is a command. cd is change directory. Ignore ls
            # Perform directory change
            if splitLine[2] == "..":
                # Go to parentID node
                self.currentNode = self.nodes[self.currentNode].parentID
                print("cd up 1 level. New ID =", self.currentNode)
            else:
                # Lookup ID of node we are changing to
                # Look in current directory, unless root ("/")
                newDir = splitLine[2]
                if newDir == "/":
                    newID = 0
                else:
                    for childID in self.nodes[self.currentNode].childrenID:
                        if self.nodes[childID].name == newDir:
                            newID = childID
        
                self.currentNode = newID
                print("new dir =", newDir)
                print("new ID =", newID)
                print("Current ID =", self.currentNode)
                
        elif splitLine[0] == "$" and splitLine[1] == "ls":
            # Do nothing
            print("Do noting, listing contents.")
        
        elif splitLine[0] == "dir":
            #Create child node with parent's ID
            #Add node to tree
            dirName = splitLine[1]
            newNodeID = len(self.nodes) # Will be new element in list, index = current len
            parentID = self.currentNode
            
            child = node(dirName, newNodeID, parentID)
            print("Node created. Node name =", child.name, "Node ID =", child.ID, "Node parent =", child.parentID)
            self.addNode(child)
            
        else:
            #Line is specifying a file and size
            #Store in current node, Split filename and size
            filesize = float(splitLine[0])
            file = splitLine[1]
            self.nodes[self.currentNode].addFile(filesize, file)
            print("Added file. Size = ", self.nodes[self.currentNode].filesizes[-1])
            print("Added file. Name = ", self.nodes[self.currentNode].files[-1])
            
    def addNode(self, newNode):
        """ Adds a new child node (sub directory """
        # Store node and name:ID lookup
        self.nodes.append(newNode)
        self.nodeIDs.update({newNode.name : newNode.ID})

        # Add ID to children of current node
        self.nodes[self.currentNode].addChild(newNode.ID)
        print("Add child to current node -", self.nodes[self.currentNode].ID)
        print("Added child ID -", self.nodes[self.currentNode].childrenID[-1])
        
    def sum_contents(self):
        """ Sums up the files in each directory """
        for node in self.nodes:
            node.total_contents_size = sum(node.filesizes)
            
    def nodeSweep(self, nodeID):
        """ Sweep through each branch of the tree, and add up the node (directory) sizes recursively """
        print("\n")
        print("Node ID =", nodeID)
        current_node = self.nodes[nodeID]
        
        if current_node.childrenID:
            # If the node has children, call this function recursively for each child
            print(f"Node {nodeID} has children - {current_node.childrenID}")
            
            for childID in current_node.childrenID:
                print(f"Swapping to child node ID - {childID}")
                child = self.nodes[childID]
                self.nodeSweep(childID)
                current_node.total_node_size = current_node.total_node_size + child.total_node_size
            
            # After the children have all been added, add the contents (files) at this level too
            current_node.total_node_size = current_node.total_node_size + current_node.total_contents_size
            print(f"Node ID {nodeID} size is now {current_node.total_node_size}")
            
        else:
            # If the node has no children, you have reached a leaf of the tree. Take the size of the contents
            print(f"Node {nodeID} has no children")
            current_node.total_node_size = current_node.total_contents_size
            print(f"Node {nodeID} size = {current_node.total_node_size}")
    
    def getAnswer(self, thresholdSize):
        """ Calculates the sum of all nodes below a threshold size"""
        self.nodeSizes = [node.total_node_size for node in self.nodes]
        applicableNodeSizes = [size for size in self.nodeSizes if size <= thresholdSize]

        print("\n")
        print("Answer =", sum(applicableNodeSizes))

# %%
# Read input data
file = "input.txt"

with open(file) as f:
    # Split terminal output into a list of strings for each line
    terminal_out =f.read().split("\n")

del terminal_out[-1] # Delete empty last line

# %%
# PART 1 
data = tree(terminal_out)
# Out:
# READING LINES
# ----------------------
# line $ cd /
# new dir = /
# new ID = 0
# Current ID = 0
# line $ ls
# Do noting, listing contents.
# line 187585 dgflmqwt.srm
# Added file. Size =  187585.0
# Added file. Name =  dgflmqwt.srm
# line dir gnpd
# Node created. Node name = gnpd Node ID = 1 Node parent = 0
# Add child to current node - 0
# Added child ID - 1
# line 200058 hbnlqs
# Added file. Size =  200058.0
# Added file. Name =  hbnlqs
# line dir jsv
# Node created. Node name = jsv Node ID = 2 Node parent = 0
# Add child to current node - 0
# Added child ID - 2
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 3 Node parent = 0
# Add child to current node - 0
# Added child ID - 3
# line dir nljtr
# Node created. Node name = nljtr Node ID = 4 Node parent = 0
# Add child to current node - 0
# Added child ID - 4
# line dir nwzp
# Node created. Node name = nwzp Node ID = 5 Node parent = 0
# Add child to current node - 0
# Added child ID - 5
# line 61949 qdswp.wfj
# Added file. Size =  61949.0
# Added file. Name =  qdswp.wfj
# line 21980 rbq.hpj
# Added file. Size =  21980.0
# Added file. Name =  rbq.hpj
# line dir rfwwwgr
# Node created. Node name = rfwwwgr Node ID = 6 Node parent = 0
# Add child to current node - 0
# Added child ID - 6
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 7 Node parent = 0
# Add child to current node - 0
# Added child ID - 7
# line dir zhfl
# Node created. Node name = zhfl Node ID = 8 Node parent = 0
# Add child to current node - 0
# Added child ID - 8
# line 136762 zwg
# Added file. Size =  136762.0
# Added file. Name =  zwg
# line $ cd gnpd
# new dir = gnpd
# new ID = 1
# Current ID = 1
# line $ ls
# Do noting, listing contents.
# line dir dcqq
# Node created. Node name = dcqq Node ID = 9 Node parent = 1
# Add child to current node - 1
# Added child ID - 9
# line dir dnscfz
# Node created. Node name = dnscfz Node ID = 10 Node parent = 1
# Add child to current node - 1
# Added child ID - 10
# line dir dwqbhgc
# Node created. Node name = dwqbhgc Node ID = 11 Node parent = 1
# Add child to current node - 1
# Added child ID - 11
# line dir lsrb
# Node created. Node name = lsrb Node ID = 12 Node parent = 1
# Add child to current node - 1
# Added child ID - 12
# line 167581 ndwfr.pbv
# Added file. Size =  167581.0
# Added file. Name =  ndwfr.pbv
# line dir pbgrdvmc
# Node created. Node name = pbgrdvmc Node ID = 13 Node parent = 1
# Add child to current node - 1
# Added child ID - 13
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 14 Node parent = 1
# Add child to current node - 1
# Added child ID - 14
# line 144703 sct
# Added file. Size =  144703.0
# Added file. Name =  sct
# line dir smfhldss
# Node created. Node name = smfhldss Node ID = 15 Node parent = 1
# Add child to current node - 1
# Added child ID - 15
# line $ cd dcqq
# new dir = dcqq
# new ID = 9
# Current ID = 9
# line $ ls
# Do noting, listing contents.
# line dir bfdng
# Node created. Node name = bfdng Node ID = 16 Node parent = 9
# Add child to current node - 9
# Added child ID - 16
# line 155230 mfhzl.bpw
# Added file. Size =  155230.0
# Added file. Name =  mfhzl.bpw
# line dir mhpqqq
# Node created. Node name = mhpqqq Node ID = 17 Node parent = 9
# Add child to current node - 9
# Added child ID - 17
# line dir mpbpcv
# Node created. Node name = mpbpcv Node ID = 18 Node parent = 9
# Add child to current node - 9
# Added child ID - 18
# line 24140 mrrznmvr.mmz
# Added file. Size =  24140.0
# Added file. Name =  mrrznmvr.mmz
# line $ cd bfdng
# new dir = bfdng
# new ID = 16
# Current ID = 16
# line $ ls
# Do noting, listing contents.
# line dir hjlch
# Node created. Node name = hjlch Node ID = 19 Node parent = 16
# Add child to current node - 16
# Added child ID - 19
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 20 Node parent = 16
# Add child to current node - 16
# Added child ID - 20
# line $ cd hjlch
# new dir = hjlch
# new ID = 19
# Current ID = 19
# line $ ls
# Do noting, listing contents.
# line 239759 sct
# Added file. Size =  239759.0
# Added file. Name =  sct
# line $ cd ..
# cd up 1 level. New ID = 16
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 20
# Current ID = 20
# line $ ls
# Do noting, listing contents.
# line 221334 hbnlqs
# Added file. Size =  221334.0
# Added file. Name =  hbnlqs
# line $ cd ..
# cd up 1 level. New ID = 16
# line $ cd ..
# cd up 1 level. New ID = 9
# line $ cd mhpqqq
# new dir = mhpqqq
# new ID = 17
# Current ID = 17
# line $ ls
# Do noting, listing contents.
# line 250305 nfqs.crt
# Added file. Size =  250305.0
# Added file. Name =  nfqs.crt
# line dir qqhz
# Node created. Node name = qqhz Node ID = 21 Node parent = 17
# Add child to current node - 17
# Added child ID - 21
# line 60892 rbq.hpj
# Added file. Size =  60892.0
# Added file. Name =  rbq.hpj
# line 64587 tbzlnq
# Added file. Size =  64587.0
# Added file. Name =  tbzlnq
# line dir tcbgmw
# Node created. Node name = tcbgmw Node ID = 22 Node parent = 17
# Add child to current node - 17
# Added child ID - 22
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 23 Node parent = 17
# Add child to current node - 17
# Added child ID - 23
# line $ cd qqhz
# new dir = qqhz
# new ID = 21
# Current ID = 21
# line $ ls
# Do noting, listing contents.
# line 148009 sct
# Added file. Size =  148009.0
# Added file. Name =  sct
# line $ cd ..
# cd up 1 level. New ID = 17
# line $ cd tcbgmw
# new dir = tcbgmw
# new ID = 22
# Current ID = 22
# line $ ls
# Do noting, listing contents.
# line 85006 sbnhc
# Added file. Size =  85006.0
# Added file. Name =  sbnhc
# line $ cd ..
# cd up 1 level. New ID = 17
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 23
# Current ID = 23
# line $ ls
# Do noting, listing contents.
# line 21720 vsrrhvlt.qbs
# Added file. Size =  21720.0
# Added file. Name =  vsrrhvlt.qbs
# line $ cd ..
# cd up 1 level. New ID = 17
# line $ cd ..
# cd up 1 level. New ID = 9
# line $ cd mpbpcv
# new dir = mpbpcv
# new ID = 18
# Current ID = 18
# line $ ls
# Do noting, listing contents.
# line 146794 bdpld.ddm
# Added file. Size =  146794.0
# Added file. Name =  bdpld.ddm
# line $ cd ..
# cd up 1 level. New ID = 9
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd dnscfz
# new dir = dnscfz
# new ID = 10
# Current ID = 10
# line $ ls
# Do noting, listing contents.
# line 276175 mfhzl.ndh
# Added file. Size =  276175.0
# Added file. Name =  mfhzl.ndh
# line 248161 qjgzgm
# Added file. Size =  248161.0
# Added file. Name =  qjgzgm
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 24 Node parent = 10
# Add child to current node - 10
# Added child ID - 24
# line dir wwf
# Node created. Node name = wwf Node ID = 25 Node parent = 10
# Add child to current node - 10
# Added child ID - 25
# line dir zjdhldlq
# Node created. Node name = zjdhldlq Node ID = 26 Node parent = 10
# Add child to current node - 10
# Added child ID - 26
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 24
# Current ID = 24
# line $ ls
# Do noting, listing contents.
# line 130051 ftjnfc
# Added file. Size =  130051.0
# Added file. Name =  ftjnfc
# line $ cd ..
# cd up 1 level. New ID = 10
# line $ cd wwf
# new dir = wwf
# new ID = 25
# Current ID = 25
# line $ ls
# Do noting, listing contents.
# line 166550 dwvphbm.jtd
# Added file. Size =  166550.0
# Added file. Name =  dwvphbm.jtd
# line $ cd ..
# cd up 1 level. New ID = 10
# line $ cd zjdhldlq
# new dir = zjdhldlq
# new ID = 26
# Current ID = 26
# line $ ls
# Do noting, listing contents.
# line 345090 hbnlqs
# Added file. Size =  345090.0
# Added file. Name =  hbnlqs
# line $ cd ..
# cd up 1 level. New ID = 10
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd dwqbhgc
# new dir = dwqbhgc
# new ID = 11
# Current ID = 11
# line $ ls
# Do noting, listing contents.
# line 310228 dwvphbm
# Added file. Size =  310228.0
# Added file. Name =  dwvphbm
# line 157686 hbnlqs
# Added file. Size =  157686.0
# Added file. Name =  hbnlqs
# line 48014 nfqs.crt
# Added file. Size =  48014.0
# Added file. Name =  nfqs.crt
# line 333356 rwb.njl
# Added file. Size =  333356.0
# Added file. Name =  rwb.njl
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 27 Node parent = 11
# Add child to current node - 11
# Added child ID - 27
# line 139174 sct
# Added file. Size =  139174.0
# Added file. Name =  sct
# line dir vjcl
# Node created. Node name = vjcl Node ID = 28 Node parent = 11
# Add child to current node - 11
# Added child ID - 28
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 27
# Current ID = 27
# line $ ls
# Do noting, listing contents.
# line 51605 bfqw.cjd
# Added file. Size =  51605.0
# Added file. Name =  bfqw.cjd
# line 267184 fjvmbpf
# Added file. Size =  267184.0
# Added file. Name =  fjvmbpf
# line 169122 mfhzl.jrp
# Added file. Size =  169122.0
# Added file. Name =  mfhzl.jrp
# line 243630 sbnhc
# Added file. Size =  243630.0
# Added file. Name =  sbnhc
# line $ cd ..
# cd up 1 level. New ID = 11
# line $ cd vjcl
# new dir = vjcl
# new ID = 28
# Current ID = 28
# line $ ls
# Do noting, listing contents.
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 29 Node parent = 28
# Add child to current node - 28
# Added child ID - 29
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 29
# Current ID = 29
# line $ ls
# Do noting, listing contents.
# line 302243 dcqq.djc
# Added file. Size =  302243.0
# Added file. Name =  dcqq.djc
# line $ cd ..
# cd up 1 level. New ID = 28
# line $ cd ..
# cd up 1 level. New ID = 11
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd lsrb
# new dir = lsrb
# new ID = 12
# Current ID = 12
# line $ ls
# Do noting, listing contents.
# line 311814 dcqq.prd
# Added file. Size =  311814.0
# Added file. Name =  dcqq.prd
# line 200118 rbq.hpj
# Added file. Size =  200118.0
# Added file. Name =  rbq.hpj
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd pbgrdvmc
# new dir = pbgrdvmc
# new ID = 13
# Current ID = 13
# line $ ls
# Do noting, listing contents.
# line 119324 cqhdvmzp.npw
# Added file. Size =  119324.0
# Added file. Name =  cqhdvmzp.npw
# line 277930 jhlrpmqg
# Added file. Size =  277930.0
# Added file. Name =  jhlrpmqg
# line dir jlcqmq
# Node created. Node name = jlcqmq Node ID = 30 Node parent = 13
# Add child to current node - 13
# Added child ID - 30
# line 204425 pddmq
# Added file. Size =  204425.0
# Added file. Name =  pddmq
# line dir rqmhwhc
# Node created. Node name = rqmhwhc Node ID = 31 Node parent = 13
# Add child to current node - 13
# Added child ID - 31
# line 257084 sbnhc
# Added file. Size =  257084.0
# Added file. Name =  sbnhc
# line 338348 vnlmlq
# Added file. Size =  338348.0
# Added file. Name =  vnlmlq
# line $ cd jlcqmq
# new dir = jlcqmq
# new ID = 30
# Current ID = 30
# line $ ls
# Do noting, listing contents.
# line 24876 mfhzl
# Added file. Size =  24876.0
# Added file. Name =  mfhzl
# line $ cd ..
# cd up 1 level. New ID = 13
# line $ cd rqmhwhc
# new dir = rqmhwhc
# new ID = 31
# Current ID = 31
# line $ ls
# Do noting, listing contents.
# line 36575 dlft.dtp
# Added file. Size =  36575.0
# Added file. Name =  dlft.dtp
# line $ cd ..
# cd up 1 level. New ID = 13
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 14
# Current ID = 14
# line $ ls
# Do noting, listing contents.
# line dir sbq
# Node created. Node name = sbq Node ID = 32 Node parent = 14
# Add child to current node - 14
# Added child ID - 32
# line dir vmslnrmc
# Node created. Node name = vmslnrmc Node ID = 33 Node parent = 14
# Add child to current node - 14
# Added child ID - 33
# line $ cd sbq
# new dir = sbq
# new ID = 32
# Current ID = 32
# line $ ls
# Do noting, listing contents.
# line 15689 hpzgsl.svb
# Added file. Size =  15689.0
# Added file. Name =  hpzgsl.svb
# line $ cd ..
# cd up 1 level. New ID = 14
# line $ cd vmslnrmc
# new dir = vmslnrmc
# new ID = 33
# Current ID = 33
# line $ ls
# Do noting, listing contents.
# line dir lcqpws
# Node created. Node name = lcqpws Node ID = 34 Node parent = 33
# Add child to current node - 33
# Added child ID - 34
# line 136481 nfqs.crt
# Added file. Size =  136481.0
# Added file. Name =  nfqs.crt
# line 29838 sbnhc
# Added file. Size =  29838.0
# Added file. Name =  sbnhc
# line $ cd lcqpws
# new dir = lcqpws
# new ID = 34
# Current ID = 34
# line $ ls
# Do noting, listing contents.
# line 168866 dcqq.pdp
# Added file. Size =  168866.0
# Added file. Name =  dcqq.pdp
# line 322264 jmtwr.fzj
# Added file. Size =  322264.0
# Added file. Name =  jmtwr.fzj
# line 18732 sct
# Added file. Size =  18732.0
# Added file. Name =  sct
# line $ cd ..
# cd up 1 level. New ID = 33
# line $ cd ..
# cd up 1 level. New ID = 14
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd smfhldss
# new dir = smfhldss
# new ID = 15
# Current ID = 15
# line $ ls
# Do noting, listing contents.
# line dir wfbssqj
# Node created. Node name = wfbssqj Node ID = 35 Node parent = 15
# Add child to current node - 15
# Added child ID - 35
# line $ cd wfbssqj
# new dir = wfbssqj
# new ID = 35
# Current ID = 35
# line $ ls
# Do noting, listing contents.
# line 134050 tgghrp.hjq
# Added file. Size =  134050.0
# Added file. Name =  tgghrp.hjq
# line $ cd ..
# cd up 1 level. New ID = 15
# line $ cd ..
# cd up 1 level. New ID = 1
# line $ cd ..
# cd up 1 level. New ID = 0
# line $ cd jsv
# new dir = jsv
# new ID = 2
# Current ID = 2
# line $ ls
# Do noting, listing contents.
# line dir bwc
# Node created. Node name = bwc Node ID = 36 Node parent = 2
# Add child to current node - 2
# Added child ID - 36
# line dir dcqq
# Node created. Node name = dcqq Node ID = 37 Node parent = 2
# Add child to current node - 2
# Added child ID - 37
# line 260913 lzcqm.wzr
# Added file. Size =  260913.0
# Added file. Name =  lzcqm.wzr
# line dir rhstw
# Node created. Node name = rhstw Node ID = 38 Node parent = 2
# Add child to current node - 2
# Added child ID - 38
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 39 Node parent = 2
# Add child to current node - 2
# Added child ID - 39
# line $ cd bwc
# new dir = bwc
# new ID = 36
# Current ID = 36
# line $ ls
# Do noting, listing contents.
# line 221975 bdv.mfq
# Added file. Size =  221975.0
# Added file. Name =  bdv.mfq
# line dir crbnzrtw
# Node created. Node name = crbnzrtw Node ID = 40 Node parent = 36
# Add child to current node - 36
# Added child ID - 40
# line dir dcqq
# Node created. Node name = dcqq Node ID = 41 Node parent = 36
# Add child to current node - 36
# Added child ID - 41
# line dir gdgh
# Node created. Node name = gdgh Node ID = 42 Node parent = 36
# Add child to current node - 36
# Added child ID - 42
# line 101246 gqcfrzmn
# Added file. Size =  101246.0
# Added file. Name =  gqcfrzmn
# line dir gsst
# Node created. Node name = gsst Node ID = 43 Node parent = 36
# Add child to current node - 36
# Added child ID - 43
# line dir jwrhclh
# Node created. Node name = jwrhclh Node ID = 44 Node parent = 36
# Add child to current node - 36
# Added child ID - 44
# line dir nbwfdvsv
# Node created. Node name = nbwfdvsv Node ID = 45 Node parent = 36
# Add child to current node - 36
# Added child ID - 45
# line dir qnwhfv
# Node created. Node name = qnwhfv Node ID = 46 Node parent = 36
# Add child to current node - 36
# Added child ID - 46
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 47 Node parent = 36
# Add child to current node - 36
# Added child ID - 47
# line $ cd crbnzrtw
# new dir = crbnzrtw
# new ID = 40
# Current ID = 40
# line $ ls
# Do noting, listing contents.
# line dir dmmpcrz
# Node created. Node name = dmmpcrz Node ID = 48 Node parent = 40
# Add child to current node - 40
# Added child ID - 48
# line 204859 dwvphbm.csz
# Added file. Size =  204859.0
# Added file. Name =  dwvphbm.csz
# line dir jdh
# Node created. Node name = jdh Node ID = 49 Node parent = 40
# Add child to current node - 40
# Added child ID - 49
# line dir mpgdhg
# Node created. Node name = mpgdhg Node ID = 50 Node parent = 40
# Add child to current node - 40
# Added child ID - 50
# line 202360 nfqs.crt
# Added file. Size =  202360.0
# Added file. Name =  nfqs.crt
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 51 Node parent = 40
# Add child to current node - 40
# Added child ID - 51
# line 302165 scpq.gpd
# Added file. Size =  302165.0
# Added file. Name =  scpq.gpd
# line dir shfhmdw
# Node created. Node name = shfhmdw Node ID = 52 Node parent = 40
# Add child to current node - 40
# Added child ID - 52
# line dir wmjgmd
# Node created. Node name = wmjgmd Node ID = 53 Node parent = 40
# Add child to current node - 40
# Added child ID - 53
# line $ cd dmmpcrz
# new dir = dmmpcrz
# new ID = 48
# Current ID = 48
# line $ ls
# Do noting, listing contents.
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 54 Node parent = 48
# Add child to current node - 48
# Added child ID - 54
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 54
# Current ID = 54
# line $ ls
# Do noting, listing contents.
# line 121861 hbnlqs
# Added file. Size =  121861.0
# Added file. Name =  hbnlqs
# line $ cd ..
# cd up 1 level. New ID = 48
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd jdh
# new dir = jdh
# new ID = 49
# Current ID = 49
# line $ ls
# Do noting, listing contents.
# line dir dwvphbm
# Node created. Node name = dwvphbm Node ID = 55 Node parent = 49
# Add child to current node - 49
# Added child ID - 55
# line $ cd dwvphbm
# new dir = dwvphbm
# new ID = 55
# Current ID = 55
# line $ ls
# Do noting, listing contents.
# line 8977 ntdtdq
# Added file. Size =  8977.0
# Added file. Name =  ntdtdq
# line $ cd ..
# cd up 1 level. New ID = 49
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd mpgdhg
# new dir = mpgdhg
# new ID = 50
# Current ID = 50
# line $ ls
# Do noting, listing contents.
# line 48235 dcqq
# Added file. Size =  48235.0
# Added file. Name =  dcqq
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 51
# Current ID = 51
# line $ ls
# Do noting, listing contents.
# line dir dbb
# Node created. Node name = dbb Node ID = 56 Node parent = 51
# Add child to current node - 51
# Added child ID - 56
# line $ cd dbb
# new dir = dbb
# new ID = 56
# Current ID = 56
# line $ ls
# Do noting, listing contents.
# line 275648 gcsdd.pdw
# Added file. Size =  275648.0
# Added file. Name =  gcsdd.pdw
# line dir rbbgrtm
# Node created. Node name = rbbgrtm Node ID = 57 Node parent = 56
# Add child to current node - 56
# Added child ID - 57
# line dir rmlm
# Node created. Node name = rmlm Node ID = 58 Node parent = 56
# Add child to current node - 56
# Added child ID - 58
# line 111336 sbnhc.qrn
# Added file. Size =  111336.0
# Added file. Name =  sbnhc.qrn
# line 153146 sct
# Added file. Size =  153146.0
# Added file. Name =  sct
# line $ cd rbbgrtm
# new dir = rbbgrtm
# new ID = 57
# Current ID = 57
# line $ ls
# Do noting, listing contents.
# line 304685 rbq.hpj
# Added file. Size =  304685.0
# Added file. Name =  rbq.hpj
# line $ cd ..
# cd up 1 level. New ID = 56
# line $ cd rmlm
# new dir = rmlm
# new ID = 58
# Current ID = 58
# line $ ls
# Do noting, listing contents.
# line dir wfr
# Node created. Node name = wfr Node ID = 59 Node parent = 58
# Add child to current node - 58
# Added child ID - 59
# line $ cd wfr
# new dir = wfr
# new ID = 59
# Current ID = 59
# line $ ls
# Do noting, listing contents.
# line 197220 dhjjr.dqq
# Added file. Size =  197220.0
# Added file. Name =  dhjjr.dqq
# line $ cd ..
# cd up 1 level. New ID = 58
# line $ cd ..
# cd up 1 level. New ID = 56
# line $ cd ..
# cd up 1 level. New ID = 51
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd shfhmdw
# new dir = shfhmdw
# new ID = 52
# Current ID = 52
# line $ ls
# Do noting, listing contents.
# line 221308 mhnfzmz.gqp
# Added file. Size =  221308.0
# Added file. Name =  mhnfzmz.gqp
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd wmjgmd
# new dir = wmjgmd
# new ID = 53
# Current ID = 53
# line $ ls
# Do noting, listing contents.
# line dir psrshrws
# Node created. Node name = psrshrws Node ID = 60 Node parent = 53
# Add child to current node - 53
# Added child ID - 60
# line dir zrtpgbg
# Node created. Node name = zrtpgbg Node ID = 61 Node parent = 53
# Add child to current node - 53
# Added child ID - 61
# line $ cd psrshrws
# new dir = psrshrws
# new ID = 60
# Current ID = 60
# line $ ls
# Do noting, listing contents.
# line 202052 twgfblm
# Added file. Size =  202052.0
# Added file. Name =  twgfblm
# line $ cd ..
# cd up 1 level. New ID = 53
# line $ cd zrtpgbg
# new dir = zrtpgbg
# new ID = 61
# Current ID = 61
# line $ ls
# Do noting, listing contents.
# line 48134 hsnzvhvm.gnp
# Added file. Size =  48134.0
# Added file. Name =  hsnzvhvm.gnp
# line $ cd ..
# cd up 1 level. New ID = 53
# line $ cd ..
# cd up 1 level. New ID = 40
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd dcqq
# new dir = dcqq
# new ID = 41
# Current ID = 41
# line $ ls
# Do noting, listing contents.
# line 63600 tlclsj.pvg
# Added file. Size =  63600.0
# Added file. Name =  tlclsj.pvg
# line 181384 tzjn
# Added file. Size =  181384.0
# Added file. Name =  tzjn
# line 90096 wgq.lrm
# Added file. Size =  90096.0
# Added file. Name =  wgq.lrm
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd gdgh
# new dir = gdgh
# new ID = 42
# Current ID = 42
# line $ ls
# Do noting, listing contents.
# line 78450 hrcdgnpv.ctz
# Added file. Size =  78450.0
# Added file. Name =  hrcdgnpv.ctz
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd gsst
# new dir = gsst
# new ID = 43
# Current ID = 43
# line $ ls
# Do noting, listing contents.
# line 345240 nfqs.crt
# Added file. Size =  345240.0
# Added file. Name =  nfqs.crt
# line 199259 sct
# Added file. Size =  199259.0
# Added file. Name =  sct
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd jwrhclh
# new dir = jwrhclh
# new ID = 44
# Current ID = 44
# line $ ls
# Do noting, listing contents.
# line dir ftjcr
# Node created. Node name = ftjcr Node ID = 62 Node parent = 44
# Add child to current node - 44
# Added child ID - 62
# line 177499 nhdh.bbn
# Added file. Size =  177499.0
# Added file. Name =  nhdh.bbn
# line dir sbnhc
# Node created. Node name = sbnhc Node ID = 63 Node parent = 44
# Add child to current node - 44
# Added child ID - 63
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 64 Node parent = 44
# Add child to current node - 44
# Added child ID - 64
# line dir wqjnwgpj
# Node created. Node name = wqjnwgpj Node ID = 65 Node parent = 44
# Add child to current node - 44
# Added child ID - 65
# line $ cd ftjcr
# new dir = ftjcr
# new ID = 62
# Current ID = 62
# line $ ls
# Do noting, listing contents.
# line dir glfptjpb
# Node created. Node name = glfptjpb Node ID = 66 Node parent = 62
# Add child to current node - 62
# Added child ID - 66
# line 121761 gqp
# Added file. Size =  121761.0
# Added file. Name =  gqp
# line 36602 lcgfmtf.zct
# Added file. Size =  36602.0
# Added file. Name =  lcgfmtf.zct
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 67 Node parent = 62
# Add child to current node - 62
# Added child ID - 67
# line dir rrrrgbqv
# Node created. Node name = rrrrgbqv Node ID = 68 Node parent = 62
# Add child to current node - 62
# Added child ID - 68
# line 236133 wdmwgzvs.jnw
# Added file. Size =  236133.0
# Added file. Name =  wdmwgzvs.jnw
# line dir zwrmjlh
# Node created. Node name = zwrmjlh Node ID = 69 Node parent = 62
# Add child to current node - 62
# Added child ID - 69
# line $ cd glfptjpb
# new dir = glfptjpb
# new ID = 66
# Current ID = 66
# line $ ls
# Do noting, listing contents.
# line dir fdnppcr
# Node created. Node name = fdnppcr Node ID = 70 Node parent = 66
# Add child to current node - 66
# Added child ID - 70
# line dir gchhnd
# Node created. Node name = gchhnd Node ID = 71 Node parent = 66
# Add child to current node - 66
# Added child ID - 71
# line dir gdphvds
# Node created. Node name = gdphvds Node ID = 72 Node parent = 66
# Add child to current node - 66
# Added child ID - 72
# line 98000 gqhv
# Added file. Size =  98000.0
# Added file. Name =  gqhv
# line $ cd fdnppcr
# new dir = fdnppcr
# new ID = 70
# Current ID = 70
# line $ ls
# Do noting, listing contents.
# line dir dwvphbm
# Node created. Node name = dwvphbm Node ID = 73 Node parent = 70
# Add child to current node - 70
# Added child ID - 73
# line dir ngsgrgp
# Node created. Node name = ngsgrgp Node ID = 74 Node parent = 70
# Add child to current node - 70
# Added child ID - 74
# line $ cd dwvphbm
# new dir = dwvphbm
# new ID = 73
# Current ID = 73
# line $ ls
# Do noting, listing contents.
# line dir wrg
# Node created. Node name = wrg Node ID = 75 Node parent = 73
# Add child to current node - 73
# Added child ID - 75
# line $ cd wrg
# new dir = wrg
# new ID = 75
# Current ID = 75
# line $ ls
# Do noting, listing contents.
# line 265022 cqhdvmzp.npw
# Added file. Size =  265022.0
# Added file. Name =  cqhdvmzp.npw
# line 316916 nfqs.crt
# Added file. Size =  316916.0
# Added file. Name =  nfqs.crt
# line $ cd ..
# cd up 1 level. New ID = 73
# line $ cd ..
# cd up 1 level. New ID = 70
# line $ cd ngsgrgp
# new dir = ngsgrgp
# new ID = 74
# Current ID = 74
# line $ ls
# Do noting, listing contents.
# line 110198 sct
# Added file. Size =  110198.0
# Added file. Name =  sct
# line $ cd ..
# cd up 1 level. New ID = 70
# line $ cd ..
# cd up 1 level. New ID = 66
# line $ cd gchhnd
# new dir = gchhnd
# new ID = 71
# Current ID = 71
# line $ ls
# Do noting, listing contents.
# line 253836 hbnlqs
# Added file. Size =  253836.0
# Added file. Name =  hbnlqs
# line 39462 mfhzl
# Added file. Size =  39462.0
# Added file. Name =  mfhzl
# line 211458 nfqs.crt
# Added file. Size =  211458.0
# Added file. Name =  nfqs.crt
# line $ cd ..
# cd up 1 level. New ID = 66
# line $ cd gdphvds
# new dir = gdphvds
# new ID = 72
# Current ID = 72
# line $ ls
# Do noting, listing contents.
# line dir dpdb
# Node created. Node name = dpdb Node ID = 76 Node parent = 72
# Add child to current node - 72
# Added child ID - 76
# line $ cd dpdb
# new dir = dpdb
# new ID = 76
# Current ID = 76
# line $ ls
# Do noting, listing contents.
# line 342610 vnlmlq
# Added file. Size =  342610.0
# Added file. Name =  vnlmlq
# line $ cd ..
# cd up 1 level. New ID = 72
# line $ cd ..
# cd up 1 level. New ID = 66
# line $ cd ..
# cd up 1 level. New ID = 62
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 67
# Current ID = 67
# line $ ls
# Do noting, listing contents.
# line dir cptj
# Node created. Node name = cptj Node ID = 77 Node parent = 67
# Add child to current node - 67
# Added child ID - 77
# line $ cd cptj
# new dir = cptj
# new ID = 77
# Current ID = 77
# line $ ls
# Do noting, listing contents.
# line 100729 nvctqj.gjw
# Added file. Size =  100729.0
# Added file. Name =  nvctqj.gjw
# line $ cd ..
# cd up 1 level. New ID = 67
# line $ cd ..
# cd up 1 level. New ID = 62
# line $ cd rrrrgbqv
# new dir = rrrrgbqv
# new ID = 68
# Current ID = 68
# line $ ls
# Do noting, listing contents.
# line 166055 dwvphbm.rvb
# Added file. Size =  166055.0
# Added file. Name =  dwvphbm.rvb
# line 303762 hbnlqs
# Added file. Size =  303762.0
# Added file. Name =  hbnlqs
# line 277411 wzr.rgz
# Added file. Size =  277411.0
# Added file. Name =  wzr.rgz
# line $ cd ..
# cd up 1 level. New ID = 62
# line $ cd zwrmjlh
# new dir = zwrmjlh
# new ID = 69
# Current ID = 69
# line $ ls
# Do noting, listing contents.
# line 32583 dvfnw
# Added file. Size =  32583.0
# Added file. Name =  dvfnw
# line $ cd ..
# cd up 1 level. New ID = 62
# line $ cd ..
# cd up 1 level. New ID = 44
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 63
# Current ID = 63
# line $ ls
# Do noting, listing contents.
# line dir hwtmwp
# Node created. Node name = hwtmwp Node ID = 78 Node parent = 63
# Add child to current node - 63
# Added child ID - 78
# line 334229 mfhzl
# Added file. Size =  334229.0
# Added file. Name =  mfhzl
# line 299303 vtrfbw.dng
# Added file. Size =  299303.0
# Added file. Name =  vtrfbw.dng
# line $ cd hwtmwp
# new dir = hwtmwp
# new ID = 78
# Current ID = 78
# line $ ls
# Do noting, listing contents.
# line dir zjmrr
# Node created. Node name = zjmrr Node ID = 79 Node parent = 78
# Add child to current node - 78
# Added child ID - 79
# line $ cd zjmrr
# new dir = zjmrr
# new ID = 79
# Current ID = 79
# line $ ls
# Do noting, listing contents.
# line 279103 cqhdvmzp.npw
# Added file. Size =  279103.0
# Added file. Name =  cqhdvmzp.npw
# line $ cd ..
# cd up 1 level. New ID = 78
# line $ cd ..
# cd up 1 level. New ID = 63
# line $ cd ..
# cd up 1 level. New ID = 44
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 64
# Current ID = 64
# line $ ls
# Do noting, listing contents.
# line dir btqsh
# Node created. Node name = btqsh Node ID = 80 Node parent = 64
# Add child to current node - 64
# Added child ID - 80
# line dir clhclcr
# Node created. Node name = clhclcr Node ID = 81 Node parent = 64
# Add child to current node - 64
# Added child ID - 81
# line 237487 cqhdvmzp.npw
# Added file. Size =  237487.0
# Added file. Name =  cqhdvmzp.npw
# line 11669 gqhltqf
# Added file. Size =  11669.0
# Added file. Name =  gqhltqf
# line 91205 hbnlqs
# Added file. Size =  91205.0
# Added file. Name =  hbnlqs
# line dir qwbnvzv
# Node created. Node name = qwbnvzv Node ID = 82 Node parent = 64
# Add child to current node - 64
# Added child ID - 82
# line 234450 rqlnhpc.qfd
# Added file. Size =  234450.0
# Added file. Name =  rqlnhpc.qfd
# line dir vbrc
# Node created. Node name = vbrc Node ID = 83 Node parent = 64
# Add child to current node - 64
# Added child ID - 83
# line dir vfdqq
# Node created. Node name = vfdqq Node ID = 84 Node parent = 64
# Add child to current node - 64
# Added child ID - 84
# line $ cd btqsh
# new dir = btqsh
# new ID = 80
# Current ID = 80
# line $ ls
# Do noting, listing contents.
# line dir lgh
# Node created. Node name = lgh Node ID = 85 Node parent = 80
# Add child to current node - 80
# Added child ID - 85
# line dir ljrjpg
# Node created. Node name = ljrjpg Node ID = 86 Node parent = 80
# Add child to current node - 80
# Added child ID - 86
# line 34333 rbq.hpj
# Added file. Size =  34333.0
# Added file. Name =  rbq.hpj
# line 15387 vzldp.ffs
# Added file. Size =  15387.0
# Added file. Name =  vzldp.ffs
# line $ cd lgh
# new dir = lgh
# new ID = 85
# Current ID = 85
# line $ ls
# Do noting, listing contents.
# line 176966 vnlmlq
# Added file. Size =  176966.0
# Added file. Name =  vnlmlq
# line $ cd ..
# cd up 1 level. New ID = 80
# line $ cd ljrjpg
# new dir = ljrjpg
# new ID = 86
# Current ID = 86
# line $ ls
# Do noting, listing contents.
# line 231230 cqhdvmzp.npw
# Added file. Size =  231230.0
# Added file. Name =  cqhdvmzp.npw
# line dir dwvphbm
# Node created. Node name = dwvphbm Node ID = 87 Node parent = 86
# Add child to current node - 86
# Added child ID - 87
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 88 Node parent = 86
# Add child to current node - 86
# Added child ID - 88
# line 251554 rdrbn.clr
# Added file. Size =  251554.0
# Added file. Name =  rdrbn.clr
# line 180447 sbnhc
# Added file. Size =  180447.0
# Added file. Name =  sbnhc
# line $ cd dwvphbm
# new dir = dwvphbm
# new ID = 87
# Current ID = 87
# line $ ls
# Do noting, listing contents.
# line dir vghvsmq
# Node created. Node name = vghvsmq Node ID = 89 Node parent = 87
# Add child to current node - 87
# Added child ID - 89
# line $ cd vghvsmq
# new dir = vghvsmq
# new ID = 89
# Current ID = 89
# line $ ls
# Do noting, listing contents.
# line 132209 cqhdvmzp.npw
# Added file. Size =  132209.0
# Added file. Name =  cqhdvmzp.npw
# line dir jqmgn
# Node created. Node name = jqmgn Node ID = 90 Node parent = 89
# Add child to current node - 89
# Added child ID - 90
# line $ cd jqmgn
# new dir = jqmgn
# new ID = 90
# Current ID = 90
# line $ ls
# Do noting, listing contents.
# line 95992 clbvg.bmr
# Added file. Size =  95992.0
# Added file. Name =  clbvg.bmr
# line $ cd ..
# cd up 1 level. New ID = 89
# line $ cd ..
# cd up 1 level. New ID = 87
# line $ cd ..
# cd up 1 level. New ID = 86
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 88
# Current ID = 88
# line $ ls
# Do noting, listing contents.
# line dir dcqq
# Node created. Node name = dcqq Node ID = 91 Node parent = 88
# Add child to current node - 88
# Added child ID - 91
# line $ cd dcqq
# new dir = dcqq
# new ID = 91
# Current ID = 91
# line $ ls
# Do noting, listing contents.
# line dir vjhl
# Node created. Node name = vjhl Node ID = 92 Node parent = 91
# Add child to current node - 91
# Added child ID - 92
# line $ cd vjhl
# new dir = vjhl
# new ID = 92
# Current ID = 92
# line $ ls
# Do noting, listing contents.
# line dir nbhmzl
# Node created. Node name = nbhmzl Node ID = 93 Node parent = 92
# Add child to current node - 92
# Added child ID - 93
# line $ cd nbhmzl
# new dir = nbhmzl
# new ID = 93
# Current ID = 93
# line $ ls
# Do noting, listing contents.
# line 155454 sbnhc.flh
# Added file. Size =  155454.0
# Added file. Name =  sbnhc.flh
# line $ cd ..
# cd up 1 level. New ID = 92
# line $ cd ..
# cd up 1 level. New ID = 91
# line $ cd ..
# cd up 1 level. New ID = 88
# line $ cd ..
# cd up 1 level. New ID = 86
# line $ cd ..
# cd up 1 level. New ID = 80
# line $ cd ..
# cd up 1 level. New ID = 64
# line $ cd clhclcr
# new dir = clhclcr
# new ID = 81
# Current ID = 81
# line $ ls
# Do noting, listing contents.
# line dir jwqwhq
# Node created. Node name = jwqwhq Node ID = 94 Node parent = 81
# Add child to current node - 81
# Added child ID - 94
# line 268077 njcmcfl.ctm
# Added file. Size =  268077.0
# Added file. Name =  njcmcfl.ctm
# line $ cd jwqwhq
# new dir = jwqwhq
# new ID = 94
# Current ID = 94
# line $ ls
# Do noting, listing contents.
# line 256988 rbq.hpj
# Added file. Size =  256988.0
# Added file. Name =  rbq.hpj
# line $ cd ..
# cd up 1 level. New ID = 81
# line $ cd ..
# cd up 1 level. New ID = 64
# line $ cd qwbnvzv
# new dir = qwbnvzv
# new ID = 82
# Current ID = 82
# line $ ls
# Do noting, listing contents.
# line 167852 dln.zrn
# Added file. Size =  167852.0
# Added file. Name =  dln.zrn
# line dir hpwpm
# Node created. Node name = hpwpm Node ID = 95 Node parent = 82
# Add child to current node - 82
# Added child ID - 95
# line 131149 lsc.tjj
# Added file. Size =  131149.0
# Added file. Name =  lsc.tjj
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 96 Node parent = 82
# Add child to current node - 82
# Added child ID - 96
# line dir mzhwwrtp
# Node created. Node name = mzhwwrtp Node ID = 97 Node parent = 82
# Add child to current node - 82
# Added child ID - 97
# line 201277 sbnhc.pfh
# Added file. Size =  201277.0
# Added file. Name =  sbnhc.pfh
# line 147232 zlmgttpl
# Added file. Size =  147232.0
# Added file. Name =  zlmgttpl
# line $ cd hpwpm
# new dir = hpwpm
# new ID = 95
# Current ID = 95
# line $ ls
# Do noting, listing contents.
# line 135194 jpzt.fjn
# Added file. Size =  135194.0
# Added file. Name =  jpzt.fjn
# line $ cd ..
# cd up 1 level. New ID = 82
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 96
# Current ID = 96
# line $ ls
# Do noting, listing contents.
# line 166015 jrcqvgf.jdg
# Added file. Size =  166015.0
# Added file. Name =  jrcqvgf.jdg
# line $ cd ..
# cd up 1 level. New ID = 82
# line $ cd mzhwwrtp
# new dir = mzhwwrtp
# new ID = 97
# Current ID = 97
# line $ ls
# Do noting, listing contents.
# line 231983 dgrvfdmp
# Added file. Size =  231983.0
# Added file. Name =  dgrvfdmp
# line 121846 dwvphbm.lvp
# Added file. Size =  121846.0
# Added file. Name =  dwvphbm.lvp
# line $ cd ..
# cd up 1 level. New ID = 82
# line $ cd ..
# cd up 1 level. New ID = 64
# line $ cd vbrc
# new dir = vbrc
# new ID = 83
# Current ID = 83
# line $ ls
# Do noting, listing contents.
# line 320029 wbhs.mpd
# Added file. Size =  320029.0
# Added file. Name =  wbhs.mpd
# line $ cd ..
# cd up 1 level. New ID = 64
# line $ cd vfdqq
# new dir = vfdqq
# new ID = 84
# Current ID = 84
# line $ ls
# Do noting, listing contents.
# line 277998 nfqs.crt
# Added file. Size =  277998.0
# Added file. Name =  nfqs.crt
# line dir qzgwglhc
# Node created. Node name = qzgwglhc Node ID = 98 Node parent = 84
# Add child to current node - 84
# Added child ID - 98
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 99 Node parent = 84
# Add child to current node - 84
# Added child ID - 99
# line 68520 wsc.vhz
# Added file. Size =  68520.0
# Added file. Name =  wsc.vhz
# line dir zfdhthfn
# Node created. Node name = zfdhthfn Node ID = 100 Node parent = 84
# Add child to current node - 84
# Added child ID - 100
# line $ cd qzgwglhc
# new dir = qzgwglhc
# new ID = 98
# Current ID = 98
# line $ ls
# Do noting, listing contents.
# line 25046 cqhdvmzp.npw
# Added file. Size =  25046.0
# Added file. Name =  cqhdvmzp.npw
# line 250876 dwvphbm
# Added file. Size =  250876.0
# Added file. Name =  dwvphbm
# line $ cd ..
# cd up 1 level. New ID = 84
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 99
# Current ID = 99
# line $ ls
# Do noting, listing contents.
# line 212688 hbnlqs
# Added file. Size =  212688.0
# Added file. Name =  hbnlqs
# line 8202 mlpl.tsp
# Added file. Size =  8202.0
# Added file. Name =  mlpl.tsp
# line 69495 vnlmlq.thv
# Added file. Size =  69495.0
# Added file. Name =  vnlmlq.thv
# line 281200 vzdwr.tbl
# Added file. Size =  281200.0
# Added file. Name =  vzdwr.tbl
# line $ cd ..
# cd up 1 level. New ID = 84
# line $ cd zfdhthfn
# new dir = zfdhthfn
# new ID = 100
# Current ID = 100
# line $ ls
# Do noting, listing contents.
# line 233242 dstb.hrs
# Added file. Size =  233242.0
# Added file. Name =  dstb.hrs
# line 269387 nfqs.crt
# Added file. Size =  269387.0
# Added file. Name =  nfqs.crt
# line $ cd ..
# cd up 1 level. New ID = 84
# line $ cd ..
# cd up 1 level. New ID = 64
# line $ cd ..
# cd up 1 level. New ID = 44
# line $ cd wqjnwgpj
# new dir = wqjnwgpj
# new ID = 65
# Current ID = 65
# line $ ls
# Do noting, listing contents.
# line dir hfd
# Node created. Node name = hfd Node ID = 101 Node parent = 65
# Add child to current node - 65
# Added child ID - 101
# line dir lbft
# Node created. Node name = lbft Node ID = 102 Node parent = 65
# Add child to current node - 65
# Added child ID - 102
# line dir rtlw
# Node created. Node name = rtlw Node ID = 103 Node parent = 65
# Add child to current node - 65
# Added child ID - 103
# line dir vbf
# Node created. Node name = vbf Node ID = 104 Node parent = 65
# Add child to current node - 65
# Added child ID - 104
# line $ cd hfd
# new dir = hfd
# new ID = 101
# Current ID = 101
# line $ ls
# Do noting, listing contents.
# line 224694 cqhdvmzp.npw
# Added file. Size =  224694.0
# Added file. Name =  cqhdvmzp.npw
# line 100103 dbmwn.tqz
# Added file. Size =  100103.0
# Added file. Name =  dbmwn.tqz
# line $ cd ..
# cd up 1 level. New ID = 65
# line $ cd lbft
# new dir = lbft
# new ID = 102
# Current ID = 102
# line $ ls
# Do noting, listing contents.
# line 60107 hbnlqs
# Added file. Size =  60107.0
# Added file. Name =  hbnlqs
# line $ cd ..
# cd up 1 level. New ID = 65
# line $ cd rtlw
# new dir = rtlw
# new ID = 103
# Current ID = 103
# line $ ls
# Do noting, listing contents.
# line dir ntpb
# Node created. Node name = ntpb Node ID = 105 Node parent = 103
# Add child to current node - 103
# Added child ID - 105
# line $ cd ntpb
# new dir = ntpb
# new ID = 105
# Current ID = 105
# line $ ls
# Do noting, listing contents.
# line 341166 mfhzl.pvj
# Added file. Size =  341166.0
# Added file. Name =  mfhzl.pvj
# line $ cd ..
# cd up 1 level. New ID = 103
# line $ cd ..
# cd up 1 level. New ID = 65
# line $ cd vbf
# new dir = vbf
# new ID = 104
# Current ID = 104
# line $ ls
# Do noting, listing contents.
# line 54177 ghrscj.tlh
# Added file. Size =  54177.0
# Added file. Name =  ghrscj.tlh
# line $ cd ..
# cd up 1 level. New ID = 65
# line $ cd ..
# cd up 1 level. New ID = 44
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd nbwfdvsv
# new dir = nbwfdvsv
# new ID = 45
# Current ID = 45
# line $ ls
# Do noting, listing contents.
# line 107273 mptw.qmn
# Added file. Size =  107273.0
# Added file. Name =  mptw.qmn
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd qnwhfv
# new dir = qnwhfv
# new ID = 46
# Current ID = 46
# line $ ls
# Do noting, listing contents.
# line 55633 hbnlqs
# Added file. Size =  55633.0
# Added file. Name =  hbnlqs
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd sbnhc
# new dir = sbnhc
# new ID = 47
# Current ID = 47
# line $ ls
# Do noting, listing contents.
# line 173163 vnlmlq
# Added file. Size =  173163.0
# Added file. Name =  vnlmlq
# line $ cd ..
# cd up 1 level. New ID = 36
# line $ cd ..
# cd up 1 level. New ID = 2
# line $ cd dcqq
# new dir = dcqq
# new ID = 37
# Current ID = 37
# line $ ls
# Do noting, listing contents.
# line 217679 hbnlqs
# Added file. Size =  217679.0
# Added file. Name =  hbnlqs
# line 146747 ltp
# Added file. Size =  146747.0
# Added file. Name =  ltp
# line $ cd ..
# cd up 1 level. New ID = 2
# line $ cd rhstw
# new dir = rhstw
# new ID = 38
# Current ID = 38
# line $ ls
# Do noting, listing contents.
# line dir clh
# Node created. Node name = clh Node ID = 106 Node parent = 38
# Add child to current node - 38
# Added child ID - 106
# line dir grz
# Node created. Node name = grz Node ID = 107 Node parent = 38
# Add child to current node - 38
# Added child ID - 107
# line dir ntjtzr
# Node created. Node name = ntjtzr Node ID = 108 Node parent = 38
# Add child to current node - 38
# Added child ID - 108
# line dir qrjgl
# Node created. Node name = qrjgl Node ID = 109 Node parent = 38
# Add child to current node - 38
# Added child ID - 109
# line dir rzqp
# Node created. Node name = rzqp Node ID = 110 Node parent = 38
# Add child to current node - 38
# Added child ID - 110
# line dir tzgrs
# Node created. Node name = tzgrs Node ID = 111 Node parent = 38
# Add child to current node - 38
# Added child ID - 111
# line dir zrdh
# Node created. Node name = zrdh Node ID = 112 Node parent = 38
# Add child to current node - 38
# Added child ID - 112
# line $ cd clh
# new dir = clh
# new ID = 106
# Current ID = 106
# line $ ls
# Do noting, listing contents.
# line 212153 cqhdvmzp.npw
# Added file. Size =  212153.0
# Added file. Name =  cqhdvmzp.npw
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd grz
# new dir = grz
# new ID = 107
# Current ID = 107
# line $ ls
# Do noting, listing contents.
# line 346002 cqhdvmzp.npw
# Added file. Size =  346002.0
# Added file. Name =  cqhdvmzp.npw
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd ntjtzr
# new dir = ntjtzr
# new ID = 108
# Current ID = 108
# line $ ls
# Do noting, listing contents.
# line 271549 rbq.hpj
# Added file. Size =  271549.0
# Added file. Name =  rbq.hpj
# line 308693 sbnhc.zrv
# Added file. Size =  308693.0
# Added file. Name =  sbnhc.zrv
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd qrjgl
# new dir = qrjgl
# new ID = 109
# Current ID = 109
# line $ ls
# Do noting, listing contents.
# line 119344 jfshwj
# Added file. Size =  119344.0
# Added file. Name =  jfshwj
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd rzqp
# new dir = rzqp
# new ID = 110
# Current ID = 110
# line $ ls
# Do noting, listing contents.
# line 327891 dcqq
# Added file. Size =  327891.0
# Added file. Name =  dcqq
# line 210282 hlmnv.jph
# Added file. Size =  210282.0
# Added file. Name =  hlmnv.jph
# line 118199 nfqs.crt
# Added file. Size =  118199.0
# Added file. Name =  nfqs.crt
# line dir rwh
# Node created. Node name = rwh Node ID = 113 Node parent = 110
# Add child to current node - 110
# Added child ID - 113
# line $ cd rwh
# new dir = rwh
# new ID = 113
# Current ID = 113
# line $ ls
# Do noting, listing contents.
# line 285057 rmvrnb
# Added file. Size =  285057.0
# Added file. Name =  rmvrnb
# line $ cd ..
# cd up 1 level. New ID = 110
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd tzgrs
# new dir = tzgrs
# new ID = 111
# Current ID = 111
# line $ ls
# Do noting, listing contents.
# line 23830 cjqrr
# Added file. Size =  23830.0
# Added file. Name =  cjqrr
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd zrdh
# new dir = zrdh
# new ID = 112
# Current ID = 112
# line $ ls
# Do noting, listing contents.
# line dir dcqq
# Node created. Node name = dcqq Node ID = 114 Node parent = 112
# Add child to current node - 112
# Added child ID - 114
# line dir dwvphbm
# Node created. Node name = dwvphbm Node ID = 115 Node parent = 112
# Add child to current node - 112
# Added child ID - 115
# line 188911 rbq.hpj
# Added file. Size =  188911.0
# Added file. Name =  rbq.hpj
# line dir vpnzs
# Node created. Node name = vpnzs Node ID = 116 Node parent = 112
# Add child to current node - 112
# Added child ID - 116
# line $ cd dcqq
# new dir = dcqq
# new ID = 114
# Current ID = 114
# line $ ls
# Do noting, listing contents.
# line 277454 hbnlqs
# Added file. Size =  277454.0
# Added file. Name =  hbnlqs
# line dir jnncgzgm
# Node created. Node name = jnncgzgm Node ID = 117 Node parent = 114
# Add child to current node - 114
# Added child ID - 117
# line $ cd jnncgzgm
# new dir = jnncgzgm
# new ID = 117
# Current ID = 117
# line $ ls
# Do noting, listing contents.
# line 199664 dcqq.tgm
# Added file. Size =  199664.0
# Added file. Name =  dcqq.tgm
# line $ cd ..
# cd up 1 level. New ID = 114
# line $ cd ..
# cd up 1 level. New ID = 112
# line $ cd dwvphbm
# new dir = dwvphbm
# new ID = 115
# Current ID = 115
# line $ ls
# Do noting, listing contents.
# line 221700 fgnznr.dhf
# Added file. Size =  221700.0
# Added file. Name =  fgnznr.dhf
# line $ cd ..
# cd up 1 level. New ID = 112
# line $ cd vpnzs
# new dir = vpnzs
# new ID = 116
# Current ID = 116
# line $ ls
# Do noting, listing contents.
# line 254459 fvcf.zcj
# Added file. Size =  254459.0
# Added file. Name =  fvcf.zcj
# line $ cd ..
# cd up 1 level. New ID = 112
# line $ cd ..
# cd up 1 level. New ID = 38
# line $ cd ..
# cd up 1 level. New ID = 2
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 39
# Current ID = 39
# line $ ls
# Do noting, listing contents.
# line dir gfsj
# Node created. Node name = gfsj Node ID = 118 Node parent = 39
# Add child to current node - 39
# Added child ID - 118
# line $ cd gfsj
# new dir = gfsj
# new ID = 118
# Current ID = 118
# line $ ls
# Do noting, listing contents.
# line dir hddvr
# Node created. Node name = hddvr Node ID = 119 Node parent = 118
# Add child to current node - 118
# Added child ID - 119
# line $ cd hddvr
# new dir = hddvr
# new ID = 119
# Current ID = 119
# line $ ls
# Do noting, listing contents.
# line dir mqmnzb
# Node created. Node name = mqmnzb Node ID = 120 Node parent = 119
# Add child to current node - 119
# Added child ID - 120
# line $ cd mqmnzb
# new dir = mqmnzb
# new ID = 120
# Current ID = 120
# line $ ls
# Do noting, listing contents.
# line 341835 jjjh
# Added file. Size =  341835.0
# Added file. Name =  jjjh
# line $ cd ..
# cd up 1 level. New ID = 119
# line $ cd ..
# cd up 1 level. New ID = 118
# line $ cd ..
# cd up 1 level. New ID = 39
# line $ cd ..
# cd up 1 level. New ID = 2
# line $ cd ..
# cd up 1 level. New ID = 0
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 3
# Current ID = 3
# line $ ls
# Do noting, listing contents.
# line dir pccldwf
# Node created. Node name = pccldwf Node ID = 121 Node parent = 3
# Add child to current node - 3
# Added child ID - 121
# line $ cd pccldwf
# new dir = pccldwf
# new ID = 121
# Current ID = 121
# line $ ls
# Do noting, listing contents.
# line 126977 nvcw
# Added file. Size =  126977.0
# Added file. Name =  nvcw
# line 318605 rljpfnc.dzd
# Added file. Size =  318605.0
# Added file. Name =  rljpfnc.dzd
# line $ cd ..
# cd up 1 level. New ID = 3
# line $ cd ..
# cd up 1 level. New ID = 0
# line $ cd nljtr
# new dir = nljtr
# new ID = 4
# Current ID = 4
# line $ ls
# Do noting, listing contents.
# line dir slztzqd
# Node created. Node name = slztzqd Node ID = 122 Node parent = 4
# Add child to current node - 4
# Added child ID - 122
# line $ cd slztzqd
# new dir = slztzqd
# new ID = 122
# Current ID = 122
# line $ ls
# Do noting, listing contents.
# line 55754 bpwghjpg.bfq
# Added file. Size =  55754.0
# Added file. Name =  bpwghjpg.bfq
# line 205753 pfplh
# Added file. Size =  205753.0
# Added file. Name =  pfplh
# line 319151 vdlmjj.mmn
# Added file. Size =  319151.0
# Added file. Name =  vdlmjj.mmn
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 123 Node parent = 122
# Add child to current node - 122
# Added child ID - 123
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 123
# Current ID = 123
# line $ ls
# Do noting, listing contents.
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 124 Node parent = 123
# Add child to current node - 123
# Added child ID - 124
# line 338081 zhjrrs
# Added file. Size =  338081.0
# Added file. Name =  zhjrrs
# line dir zpj
# Node created. Node name = zpj Node ID = 125 Node parent = 123
# Add child to current node - 123
# Added child ID - 125
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 124
# Current ID = 124
# line $ ls
# Do noting, listing contents.
# line dir dcqq
# Node created. Node name = dcqq Node ID = 126 Node parent = 124
# Add child to current node - 124
# Added child ID - 126
# line dir lgfb
# Node created. Node name = lgfb Node ID = 127 Node parent = 124
# Add child to current node - 124
# Added child ID - 127
# line dir rjbprpnl
# Node created. Node name = rjbprpnl Node ID = 128 Node parent = 124
# Add child to current node - 124
# Added child ID - 128
# line 343125 vnlmlq.zpr
# Added file. Size =  343125.0
# Added file. Name =  vnlmlq.zpr
# line $ cd dcqq
# new dir = dcqq
# new ID = 126
# Current ID = 126
# line $ ls
# Do noting, listing contents.
# line 288030 rbq.hpj
# Added file. Size =  288030.0
# Added file. Name =  rbq.hpj
# line $ cd ..
# cd up 1 level. New ID = 124
# line $ cd lgfb
# new dir = lgfb
# new ID = 127
# Current ID = 127
# line $ ls
# Do noting, listing contents.
# line 22119 cqhdvmzp.npw
# Added file. Size =  22119.0
# Added file. Name =  cqhdvmzp.npw
# line 238775 wbmnzgt.vnl
# Added file. Size =  238775.0
# Added file. Name =  wbmnzgt.vnl
# line $ cd ..
# cd up 1 level. New ID = 124
# line $ cd rjbprpnl
# new dir = rjbprpnl
# new ID = 128
# Current ID = 128
# line $ ls
# Do noting, listing contents.
# line 244896 lvgg.jvz
# Added file. Size =  244896.0
# Added file. Name =  lvgg.jvz
# line $ cd ..
# cd up 1 level. New ID = 124
# line $ cd ..
# cd up 1 level. New ID = 123
# line $ cd zpj
# new dir = zpj
# new ID = 125
# Current ID = 125
# line $ ls
# Do noting, listing contents.
# line 339679 dcqq
# Added file. Size =  339679.0
# Added file. Name =  dcqq
# line $ cd ..
# cd up 1 level. New ID = 123
# line $ cd ..
# cd up 1 level. New ID = 122
# line $ cd ..
# cd up 1 level. New ID = 4
# line $ cd ..
# cd up 1 level. New ID = 0
# line $ cd nwzp
# new dir = nwzp
# new ID = 5
# Current ID = 5
# line $ ls
# Do noting, listing contents.
# line dir mfhzl
# Node created. Node name = mfhzl Node ID = 129 Node parent = 5
# Add child to current node - 5
# Added child ID - 129
# line dir vnlmlq
# Node created. Node name = vnlmlq Node ID = 130 Node parent = 5
# Add child to current node - 5
# Added child ID - 130
# line $ cd mfhzl
# new dir = mfhzl
# new ID = 129
# Current ID = 129
# line $ ls
# Do noting, listing contents.
# line 107297 dwvphbm.nvb
# Added file. Size =  107297.0
# Added file. Name =  dwvphbm.nvb
# line $ cd ..
# cd up 1 level. New ID = 5
# line $ cd vnlmlq
# new dir = vnlmlq
# new ID = 130
# Current ID = 130
# line $ ls
# Do noting, listing contents.
# line dir mdj
# Node created. Node name = mdj Node ID = 131 Node parent = 130
# Add child to current node - 130
# Added child ID - 131
# line $ cd mdj
# new dir = mdj
# new ID = 131
# Current ID = 131
# line $ ls
# Do noting, listing contents.
# line 87553 dbtct.nws
# Added file. Size =  87553.0
# Added file. Name =  dbtct.nws
# line $ cd ..
# cd up 1 level. New ID = 130
# line $ cd ..
# cd up 1 level. New ID = 5
# line $ cd ..
# cd up 1 level. New ID = 0
# line $ cd rfwwwgr
# new dir = rfwwwgr
# new ID = 6
# Current ID = 6
# line $ ls
# ...
# Swapping to child node ID - 53
#
#
# Node ID = 53
# Node 53 has children - [60, 61]
# Swapping to child node ID - 60
#
#
# Node ID = 60
# Node 60 has no children
# Node 60 size = 202052.0
# Swapping to child node ID - 61
#
#
# Node ID = 61
# Node 61 has no children
# Node 61 size = 48134.0
# Node ID 53 size is now 250186.0
# Node ID 40 size is now 2401986.0
# Swapping to child node ID - 41
#
#
# Node ID = 41
# Node 41 has no children
# Node 41 size = 335080.0
# Swapping to child node ID - 42
#
#
# Node ID = 42
# Node 42 has no children
# Node 42 size = 78450.0
# Swapping to child node ID - 43
#
#
# Node ID = 43
# Node 43 has no children
# Node 43 size = 544499.0
# Swapping to child node ID - 44
#
#
# Node ID = 44
# Node 44 has children - [62, 63, 64, 65]
# Swapping to child node ID - 62
#
#
# Node ID = 62
# Node 62 has children - [66, 67, 68, 69]
# Swapping to child node ID - 66
#
#
# Node ID = 66
# Node 66 has children - [70, 71, 72]
# Swapping to child node ID - 70
#
#
# Node ID = 70
# Node 70 has children - [73, 74]
# Swapping to child node ID - 73
#
#
# Node ID = 73
# Node 73 has children - [75]
# Swapping to child node ID - 75
#
#
# Node ID = 75
# Node 75 has no children
# Node 75 size = 581938.0
# Node ID 73 size is now 581938.0
# Swapping to child node ID - 74
#
#
# Node ID = 74
# Node 74 has no children
# Node 74 size = 110198.0
# Node ID 70 size is now 692136.0
# Swapping to child node ID - 71
#
#
# Node ID = 71
# Node 71 has no children
# Node 71 size = 504756.0
# Swapping to child node ID - 72
#
#
# Node ID = 72
# Node 72 has children - [76]
# Swapping to child node ID - 76
#
#
# Node ID = 76
# Node 76 has no children
# Node 76 size = 342610.0
# Node ID 72 size is now 342610.0
# Node ID 66 size is now 1637502.0
# Swapping to child node ID - 67
#
#
# Node ID = 67
# Node 67 has children - [77]
# Swapping to child node ID - 77
#
#
# Node ID = 77
# Node 77 has no children
# Node 77 size = 100729.0
# Node ID 67 size is now 100729.0
# Swapping to child node ID - 68
#
#
# Node ID = 68
# Node 68 has no children
# Node 68 size = 747228.0
# Swapping to child node ID - 69
#
#
# Node ID = 69
# Node 69 has no children
# Node 69 size = 32583.0
# Node ID 62 size is now 2912538.0
# Swapping to child node ID - 63
#
#
# Node ID = 63
# Node 63 has children - [78]
# Swapping to child node ID - 78
#
#
# Node ID = 78
# Node 78 has children - [79]
# Swapping to child node ID - 79
#
#
# Node ID = 79
# Node 79 has no children
# Node 79 size = 279103.0
# Node ID 78 size is now 279103.0
# Node ID 63 size is now 912635.0
# Swapping to child node ID - 64
#
#
# Node ID = 64
# Node 64 has children - [80, 81, 82, 83, 84]
# Swapping to child node ID - 80
#
#
# Node ID = 80
# Node 80 has children - [85, 86]
# Swapping to child node ID - 85
#
#
# Node ID = 85
# Node 85 has no children
# Node 85 size = 176966.0
# Swapping to child node ID - 86
#
#
# Node ID = 86
# Node 86 has children - [87, 88]
# Swapping to child node ID - 87
#
#
# Node ID = 87
# Node 87 has children - [89]
# Swapping to child node ID - 89
#
#
# Node ID = 89
# Node 89 has children - [90]
# Swapping to child node ID - 90
#
#
# Node ID = 90
# Node 90 has no children
# Node 90 size = 95992.0
# Node ID 89 size is now 228201.0
# Node ID 87 size is now 228201.0
# Swapping to child node ID - 88
#
#
# Node ID = 88
# Node 88 has children - [91]
# Swapping to child node ID - 91
#
#
# Node ID = 91
# Node 91 has children - [92]
# Swapping to child node ID - 92
#
#
# Node ID = 92
# Node 92 has children - [93]
# Swapping to child node ID - 93
#
#
# Node ID = 93
# Node 93 has no children
# Node 93 size = 155454.0
# Node ID 92 size is now 155454.0
# Node ID 91 size is now 155454.0
# Node ID 88 size is now 155454.0
# Node ID 86 size is now 1046886.0
# Node ID 80 size is now 1273572.0
# Swapping to child node ID - 81
#
#
# Node ID = 81
# Node 81 has children - [94]
# Swapping to child node ID - 94
#
#
# Node ID = 94
# Node 94 has no children
# Node 94 size = 256988.0
# Node ID 81 size is now 525065.0
# Swapping to child node ID - 82
#
#
# Node ID = 82
# Node 82 has children - [95, 96, 97]
# Swapping to child node ID - 95
#
#
# Node ID = 95
# Node 95 has no children
# Node 95 size = 135194.0
# Swapping to child node ID - 96
#
#
# Node ID = 96
# Node 96 has no children
# Node 96 size = 166015.0
# Swapping to child node ID - 97
#
#
# Node ID = 97
# Node 97 has no children
# Node 97 size = 353829.0
# Node ID 82 size is now 1302548.0
# Swapping to child node ID - 83
#
#
# Node ID = 83
# Node 83 has no children
# Node 83 size = 320029.0
# Swapping to child node ID - 84
#
#
# Node ID = 84
# Node 84 has children - [98, 99, 100]
# Swapping to child node ID - 98
#
#
# Node ID = 98
# Node 98 has no children
# Node 98 size = 275922.0
# Swapping to child node ID - 99
#
#
# Node ID = 99
# Node 99 has no children
# Node 99 size = 571585.0
# Swapping to child node ID - 100
#
#
# Node ID = 100
# Node 100 has no children
# Node 100 size = 502629.0
# Node ID 84 size is now 1696654.0
# Node ID 64 size is now 5692679.0
# Swapping to child node ID - 65
#
#
# Node ID = 65
# Node 65 has children - [101, 102, 103, 104]
# Swapping to child node ID - 101
#
#
# Node ID = 101
# Node 101 has no children
# Node 101 size = 324797.0
# Swapping to child node ID - 102
#
#
# Node ID = 102
# Node 102 has no children
# Node 102 size = 60107.0
# Swapping to child node ID - 103
#
#
# Node ID = 103
# Node 103 has children - [105]
# Swapping to child node ID - 105
#
#
# Node ID = 105
# Node 105 has no children
# Node 105 size = 341166.0
# Node ID 103 size is now 341166.0
# Swapping to child node ID - 104
#
#
# Node ID = 104
# Node 104 has no children
# Node 104 size = 54177.0
# Node ID 65 size is now 780247.0
# Node ID 44 size is now 10475598.0
# Swapping to child node ID - 45
#
#
# Node ID = 45
# Node 45 has no children
# Node 45 size = 107273.0
# Swapping to child node ID - 46
#
#
# Node ID = 46
# Node 46 has no children
# Node 46 size = 55633.0
# Swapping to child node ID - 47
#
#
# Node ID = 47
# Node 47 has no children
# Node 47 size = 173163.0
# Node ID 36 size is now 14494903.0
# Swapping to child node ID - 37
#
#
# Node ID = 37
# Node 37 has no children
# Node 37 size = 364426.0
# Swapping to child node ID - 38
#
#
# Node ID = 38
# Node 38 has children - [106, 107, 108, 109, 110, 111, 112]
# Swapping to child node ID - 106
#
#
# Node ID = 106
# Node 106 has no children
# Node 106 size = 212153.0
# Swapping to child node ID - 107
#
#
# Node ID = 107
# Node 107 has no children
# Node 107 size = 346002.0
# Swapping to child node ID - 108
#
#
# Node ID = 108
# Node 108 has no children
# Node 108 size = 580242.0
# Swapping to child node ID - 109
#
#
# Node ID = 109
# Node 109 has no children
# Node 109 size = 119344.0
# Swapping to child node ID - 110
#
#
# Node ID = 110
# Node 110 has children - [113]
# Swapping to child node ID - 113
#
#
# Node ID = 113
# Node 113 has no children
# Node 113 size = 285057.0
# Node ID 110 size is now 941429.0
# Swapping to child node ID - 111
#
#
# Node ID = 111
# Node 111 has no children
# Node 111 size = 23830.0
# Swapping to child node ID - 112
#
#
# Node ID = 112
# Node 112 has children - [114, 115, 116]
# Swapping to child node ID - 114
#
#
# Node ID = 114
# Node 114 has children - [117]
# Swapping to child node ID - 117
#
#
# Node ID = 117
# Node 117 has no children
# Node 117 size = 199664.0
# Node ID 114 size is now 477118.0
# Swapping to child node ID - 115
#
#
# Node ID = 115
# Node 115 has no children
# Node 115 size = 221700.0
# Swapping to child node ID - 116
#
#
# Node ID = 116
# Node 116 has no children
# Node 116 size = 254459.0
# Node ID 112 size is now 1142188.0
# Node ID 38 size is now 3365188.0
# Swapping to child node ID - 39
#
#
# Node ID = 39
# Node 39 has children - [118]
# Swapping to child node ID - 118
#
#
# Node ID = 118
# Node 118 has children - [119]
# Swapping to child node ID - 119
#
#
# Node ID = 119
# Node 119 has children - [120]
# Swapping to child node ID - 120
#
#
# Node ID = 120
# Node 120 has no children
# Node 120 size = 341835.0
# Node ID 119 size is now 341835.0
# Node ID 118 size is now 341835.0
# Node ID 39 size is now 341835.0
# Node ID 2 size is now 18827265.0
# Swapping to child node ID - 3
#
#
# Node ID = 3
# Node 3 has children - [121]
# Swapping to child node ID - 121
#
#
# Node ID = 121
# Node 121 has no children
# Node 121 size = 445582.0
# Node ID 3 size is now 445582.0
# Swapping to child node ID - 4
#
#
# Node ID = 4
# Node 4 has children - [122]
# Swapping to child node ID - 122
#
#
# Node ID = 122
# Node 122 has children - [123]
# Swapping to child node ID - 123
#
#
# Node ID = 123
# Node 123 has children - [124, 125]
# Swapping to child node ID - 124
#
#
# Node ID = 124
# Node 124 has children - [126, 127, 128]
# Swapping to child node ID - 126
#
#
# Node ID = 126
# Node 126 has no children
# Node 126 size = 288030.0
# Swapping to child node ID - 127
#
#
# Node ID = 127
# Node 127 has no children
# Node 127 size = 260894.0
# Swapping to child node ID - 128
#
#
# Node ID = 128
# Node 128 has no children
# Node 128 size = 244896.0
# Node ID 124 size is now 1136945.0
# Swapping to child node ID - 125
#
#
# Node ID = 125
# Node 125 has no children
# Node 125 size = 339679.0
# Node ID 123 size is now 1814705.0
# Node ID 122 size is now 2395363.0
# Node ID 4 size is now 2395363.0
# Swapping to child node ID - 5
#
#
# Node ID = 5
# Node 5 has children - [129, 130]
# Swapping to child node ID - 129
#
#
# Node ID = 129
# Node 129 has no children
# Node 129 size = 107297.0
# Swapping to child node ID - 130
#
#
# Node ID = 130
# Node 130 has children - [131]
# Swapping to child node ID - 131
#
#
# Node ID = 131
# Node 131 has no children
# Node 131 size = 87553.0
# Node ID 130 size is now 87553.0
# Node ID 5 size is now 194850.0
# Swapping to child node ID - 6
#
#
# Node ID = 6
# Node 6 has no children
# Node 6 size = 362615.0
# Swapping to child node ID - 7
#
#
# Node ID = 7
# Node 7 has children - [132]
# Swapping to child node ID - 132
#
#
# Node ID = 132
# Node 132 has no children
# Node 132 size = 21955.0
# Node ID 7 size is now 254904.0
# Swapping to child node ID - 8
#
#
# Node ID = 8
# Node 8 has children - [133, 134]
# Swapping to child node ID - 133
#
#
# Node ID = 133
# Node 133 has children - [135, 136, 137, 138]
# Swapping to child node ID - 135
#
#
# Node ID = 135
# Node 135 has no children
# Node 135 size = 293401.0
# Swapping to child node ID - 136
#
#
# Node ID = 136
# Node 136 has children - [139, 140, 141]
# Swapping to child node ID - 139
#
#
# Node ID = 139
# Node 139 has no children
# Node 139 size = 321650.0
# Swapping to child node ID - 140
#
#
# Node ID = 140
# Node 140 has children - [142, 143, 144]
# Swapping to child node ID - 142
#
#
# Node ID = 142
# Node 142 has no children
# Node 142 size = 87960.0
# Swapping to child node ID - 143
#
#
# Node ID = 143
# Node 143 has no children
# Node 143 size = 182692.0
# Swapping to child node ID - 144
#
#
# Node ID = 144
# Node 144 has no children
# Node 144 size = 491304.0
# Node ID 140 size is now 950427.0
# Swapping to child node ID - 141
#
#
# Node ID = 141
# Node 141 has children - [145, 146]
# Swapping to child node ID - 145
#
#
# Node ID = 145
# Node 145 has no children
# Node 145 size = 524886.0
# Swapping to child node ID - 146
#
#
# Node ID = 146
# Node 146 has no children
# Node 146 size = 227775.0
# Node ID 141 size is now 1373397.0
# Node ID 136 size is now 3655763.0
# Swapping to child node ID - 137
#
#
# Node ID = 137
# Node 137 has no children
# Node 137 size = 245520.0
# Swapping to child node ID - 138
#
#
# Node ID = 138
# Node 138 has children - [147, 148, 149]
# Swapping to child node ID - 147
#
#
# Node ID = 147
# Node 147 has no children
# Node 147 size = 340987.0
# Swapping to child node ID - 148
#
#
# Node ID = 148
# Node 148 has no children
# Node 148 size = 67782.0
# Swapping to child node ID - 149
#
#
# Node ID = 149
# Node 149 has no children
# Node 149 size = 156705.0
# Node ID 138 size is now 573368.0
# Node ID 133 size is now 5072507.0
# Swapping to child node ID - 134
#
#
# Node ID = 134
# Node 134 has children - [150, 151, 152, 153, 154, 155]
# Swapping to child node ID - 150
#
#
# Node ID = 150
# Node 150 has no children
# Node 150 size = 257972.0
# Swapping to child node ID - 151
#
#
# Node ID = 151
# Node 151 has children - [156, 157]
# Swapping to child node ID - 156
#
#
# Node ID = 156
# Node 156 has children - [158]
# Swapping to child node ID - 158
#
#
# Node ID = 158
# Node 158 has children - [159]
# Swapping to child node ID - 159
#
#
# Node ID = 159
# Node 159 has children - [160, 161]
# Swapping to child node ID - 160
#
#
# Node ID = 160
# Node 160 has no children
# Node 160 size = 411445.0
# Swapping to child node ID - 161
#
#
# Node ID = 161
# Node 161 has children - [162]
# Swapping to child node ID - 162
#
#
# Node ID = 162
# Node 162 has no children
# Node 162 size = 198277.0
# Node ID 161 size is now 323697.0
# Node ID 159 size is now 942339.0
# Node ID 158 size is now 1582567.0
# Node ID 156 size is now 2135740.0
# Swapping to child node ID - 157
#
#
# Node ID = 157
# Node 157 has no children
# Node 157 size = 234879.0
# Node ID 151 size is now 2756108.0
# Swapping to child node ID - 152
#
#
# Node ID = 152
# Node 152 has children - [163, 164]
# Swapping to child node ID - 163
#
#
# Node ID = 163
# Node 163 has no children
# Node 163 size = 295434.0
# Swapping to child node ID - 164
#
#
# Node ID = 164
# Node 164 has children - [165, 166]
# Swapping to child node ID - 165
#
#
# Node ID = 165
# Node 165 has children - [167]
# Swapping to child node ID - 167
#
#
# Node ID = 167
# Node 167 has no children
# Node 167 size = 271647.0
# Node ID 165 size is now 271647.0
# Swapping to child node ID - 166
#
#
# Node ID = 166
# Node 166 has children - [168]
# Swapping to child node ID - 168
#
#
# Node ID = 168
# Node 168 has no children
# Node 168 size = 28073.0
# Node ID 166 size is now 136394.0
# Node ID 164 size is now 531698.0
# Node ID 152 size is now 851442.0
# Swapping to child node ID - 153
#
#
# Node ID = 153
# Node 153 has no children
# Node 153 size = 98838.0
# Swapping to child node ID - 154
#
#
# Node ID = 154
# Node 154 has children - [169, 170, 171]
# Swapping to child node ID - 169
#
#
# Node ID = 169
# Node 169 has children - [172]
# Swapping to child node ID - 172
#
#
# Node ID = 172
# Node 172 has children - [173]
# Swapping to child node ID - 173
#
#
# Node ID = 173
# Node 173 has no children
# Node 173 size = 171935.0
# Node ID 172 size is now 685706.0
# Node ID 169 size is now 1237947.0
# Swapping to child node ID - 170
#
#
# Node ID = 170
# Node 170 has no children
# Node 170 size = 109141.0
# Swapping to child node ID - 171
#
#
# Node ID = 171
# Node 171 has children - [174, 175, 176, 177, 178]
# Swapping to child node ID - 174
#
#
# Node ID = 174
# Node 174 has no children
# Node 174 size = 195700.0
# Swapping to child node ID - 175
#
#
# Node ID = 175
# Node 175 has no children
# Node 175 size = 143105.0
# Swapping to child node ID - 176
#
#
# Node ID = 176
# Node 176 has children - [179, 180]
# Swapping to child node ID - 179
#
#
# Node ID = 179
# Node 179 has no children
# Node 179 size = 209755.0
# Swapping to child node ID - 180
#
#
# Node ID = 180
# Node 180 has no children
# Node 180 size = 335546.0
# Node ID 176 size is now 593068.0
# Swapping to child node ID - 177
#
#
# Node ID = 177
# Node 177 has children - [181]
# Swapping to child node ID - 181
#
#
# Node ID = 181
# Node 181 has no children
# Node 181 size = 80980.0
# Node ID 177 size is now 566485.0
# Swapping to child node ID - 178
#
#
# Node ID = 178
# Node 178 has no children
# Node 178 size = 153953.0
# Node ID 171 size is now 1970914.0
# Node ID 154 size is now 3500636.0
# Swapping to child node ID - 155
#
#
# Node ID = 155
# Node 155 has children - [182, 183, 184, 185]
# Swapping to child node ID - 182
#
#
# Node ID = 182
# Node 182 has no children
# Node 182 size = 342025.0
# Swapping to child node ID - 183
#
#
# Node ID = 183
# Node 183 has no children
# Node 183 size = 963746.0
# Swapping to child node ID - 184
#
#
# Node ID = 184
# Node 184 has children - [186, 187]
# Swapping to child node ID - 186
#
#
# Node ID = 186
# Node 186 has no children
# Node 186 size = 276125.0
# Swapping to child node ID - 187
#
#
# Node ID = 187
# Node 187 has children - [188, 189]
# Swapping to child node ID - 188
#
#
# Node ID = 188
# Node 188 has children - [190]
# Swapping to child node ID - 190
#
#
# Node ID = 190
# Node 190 has children - [191]
# Swapping to child node ID - 191
#
#
# Node ID = 191
# Node 191 has no children
# Node 191 size = 309244.0
# Node ID 190 size is now 309244.0
# Node ID 188 size is now 309244.0
# Swapping to child node ID - 189
#
#
# Node ID = 189
# Node 189 has no children
# Node 189 size = 69436.0
# Node ID 187 size is now 953565.0
# Node ID 184 size is now 2163788.0
# Swapping to child node ID - 185
#
#
# Node ID = 185
# Node 185 has children - [192, 193]
# Swapping to child node ID - 192
#
#
# Node ID = 192
# Node 192 has children - [194]
# Swapping to child node ID - 194
#
#
# Node ID = 194
# Node 194 has no children
# Node 194 size = 49895.0
# Node ID 192 size is now 49895.0
# Swapping to child node ID - 193
#
#
# Node ID = 193
# Node 193 has no children
# Node 193 size = 265434.0
# Node ID 185 size is now 673626.0
# Node ID 155 size is now 4979878.0
# Node ID 134 size is now 12661554.0
# Node ID 8 size is now 17914680.0
# Node ID 0 size is now 48518336.0
#
#
# Answer = 1428881.0

# %%
# PART 2
total_space = 70000000
update_space = 30000000
used_space = data.nodeSizes[0]

free_space = total_space - used_space
required_space = update_space - free_space

# Find first node size >= required_space
sizes = data.nodeSizes
sizes.sort()
sizes = [size for size in sizes if size >= required_space]

print("Answer 2 =", sizes[0])
# Out:
# Answer 2 = 10475598.0
